# %% [markdown]
# # Поиск ассоциативных правил. Снедков Валентин, ЕТ-128
# 1. Выполните поиск ассоциативных правил для набора данных из задания по поиску частых наборов. Зафиксируйте значение пороговое значение поддержки (например, 10%), варьируйте пороговое значение достоверности (например, от 70% до 95% с шагом 5%).
#
#
# * Получите список результирующих правил в удобочитаемом виде (антецедент==>консеквент).
# * Отфильтруйте правила, в которых антецедент и консеквент суммарно включают в себя не более семи объектов.
# * Проанализируйте и изложите содержательный смысл полученного результата.
#
# 2. Выполните визуализацию полученных результатов в виде следующих диаграмм:
# * сравнение быстродействия поиска правил на фиксированном наборе данных при изменяемом пороге достоверности;
# * общее количество найденных правил на фиксированном наборе данных при изменяемом пороге достоверности;
# * максимальное количество объектов в правиле на фиксированном наборе данных при изменяемом пороге достоверности;
# * количество правил, в которых антецедент и консеквент суммарно включают в себя не более семи объектов, на фиксированном наборе данных при изменяемом пороге достоверности.
# 3. Подготовьте отчет о выполнении задания и загрузите отчет в формате PDF в систему. Отчет должен представлять собой связный и структурированный документ со следующими разделами:
# * формулировка задания;
# * гиперссылка на каталог репозитория с исходными текстами, набором данных и др. сопутствующими материалами;
# * рисунки с результатами визуализации;
# * пояснения, раскрывающие смысл полученных результатов.

# %%
# Библиотеки
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from itertools import combinations
import time
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
baskets = 'baskets (2).csv'

df = pd.read_csv(baskets, sep=',', header=None, encoding='cp1251')
df.head()
# Out:
#                  0            1                        2              3   \
# 0          креветки      миндаль                  авокадо  овощная смесь
# 1         гамбургер  фрикадельки                     яйца            NaN
# 2             чатни          NaN                      NaN            NaN
# 3           индейка      авокадо                      NaN            NaN
# 4  минеральная вода       молоко  энергетический батончик            рис
#
#                  4                    5      6       7   \
# 0  зеленый виноград  цельнозерновая мука  батат  творог
# 1               NaN                  NaN    NaN     NaN
# 2               NaN                  NaN    NaN     NaN
# 3               NaN                  NaN    NaN     NaN
# 4       зеленый чай                  NaN    NaN     NaN
#
#                        8             9                       10           11  \
# 0  энергетический напиток  томатный сок  низкокалорийный йогурт  зеленый чай
# 1                     NaN           NaN                     NaN          NaN
# 2                     NaN           NaN                     NaN          NaN
# 3                     NaN           NaN                     NaN          NaN
# 4                     NaN           NaN                     NaN          NaN
#
#     12     13                14      15           16                  17  \
# 0  мед  салат  минеральная вода  лосось  ягодный сок  замороженный смузи
# 1  NaN    NaN               NaN     NaN          NaN                 NaN
# 2  NaN    NaN               NaN     NaN          NaN                 NaN
# 3  NaN    NaN               NaN     NaN          NaN                 NaN
# 4  NaN    NaN               NaN     NaN          NaN                 NaN
#
#        18               19
# 0  шпинат  оливковое масло
# 1     NaN              NaN
# 2     NaN              NaN
# 3     NaN              NaN
# 4     NaN              NaN

# %%
# one-hot преобразование транзакций
transactions = df.apply(lambda row: row.dropna().tolist(), axis=1).tolist()

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)

df_onehot = pd.DataFrame(te_array, columns=te.columns_)
# df_onehot = df_onehot.fillna(0)
df_onehot.head()
# Out:
#    авокадо  аксессуары  баклажаны  батат  батончик без глютена  бекон  \
# 0     True       False      False   True                 False  False
# 1    False       False      False  False                 False  False
# 2    False       False      False  False                 False  False
# 3     True       False      False  False                 False  False
# 4    False       False      False  False                 False  False
#
#    белое вино  белый сыр  блинчики  ветчина  ...   чили  шампанское  шампунь  \
# 0       False      False     False    False  ...  False       False    False
# 1       False      False     False    False  ...  False       False    False
# 2       False      False     False    False  ...  False       False    False
# 3       False      False     False    False  ...  False       False    False
# 4       False      False     False    False  ...  False       False    False
#
#    шоколад  шпинат  энергетический батончик  энергетический напиток  эскалоп  \
# 0    False    True                    False                    True    False
# 1    False   False                    False                   False    False
# 2    False   False                    False                   False    False
# 3    False   False                    False                   False    False
# 4    False   False                     True                   False    False
#
#    ягодный сок   яйца
# 0         True  False
# 1        False   True
# 2        False  False
# 3        False  False
# 4        False  False
#
# [5 rows x 115 columns]

# %%
min_support = 0.01                                            # Фиксируем минимальную поддержку на 10%
confidence_values = [0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.6, 0.7]       # Варьируем значение пороговой поддержки

summary_rules = []                                            # Результаты
rules_by_confidence = {}                                      # Список правил

frequent_itemsets = apriori(df_onehot,
                            min_support=min_support,
                            use_colnames=True)

for conf in confidence_values:

    print(f"Поддержка: {conf}")
    start_time = time.perf_counter()

    rules = association_rules(frequent_itemsets,
                              metric="confidence",
                              min_threshold=conf)

    end_time = time.perf_counter()
    execution_time = end_time - start_time

    if len(rules) > 0:
        rules["rule_length"] = (
            rules["antecedents"].apply(len) +
            rules["consequents"].apply(len)
        )
        max_length = rules["rule_length"].max()
    else:
        rules["rule_length"] = []
        max_length = 0

    print("┌--------------------------------------------------------┐")
    print(f"| Время: {execution_time:.4f} сек, правил: {len(rules)}, максимальная длина: {max_length}  |")
    print("└--------------------------------------------------------┘\n")

    summary_rules.append({
        "confidence": conf,
        "time_sec": execution_time,
        "total_rules": len(rules),
        "max_rule_length": max_length,
    })

    rules_by_confidence[conf] = rules
# Out:
# Поддержка: 0.1
# ┌--------------------------------------------------------┐
# | Время: 0.0087 сек, правил: 333, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.15
# ┌--------------------------------------------------------┐
# | Время: 0.0072 сек, правил: 231, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.2
# ┌--------------------------------------------------------┐
# | Время: 0.0066 сек, правил: 163, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.25
# ┌--------------------------------------------------------┐
# | Время: 0.0060 сек, правил: 99, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.3
# ┌--------------------------------------------------------┐
# | Время: 0.0054 сек, правил: 65, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.35
# ┌--------------------------------------------------------┐
# | Время: 0.0060 сек, правил: 34, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.4
# ┌--------------------------------------------------------┐
# | Время: 0.0060 сек, правил: 19, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.45
# ┌--------------------------------------------------------┐
# | Время: 0.0059 сек, правил: 6, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.5
# ┌--------------------------------------------------------┐
# | Время: 0.0039 сек, правил: 2, максимальная длина: 3  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.55
# ┌--------------------------------------------------------┐
# | Время: 0.0027 сек, правил: 0, максимальная длина: 0  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.6
# ┌--------------------------------------------------------┐
# | Время: 0.0026 сек, правил: 0, максимальная длина: 0  |
# └--------------------------------------------------------┘
#
# Поддержка: 0.7
# ┌--------------------------------------------------------┐
# | Время: 0.0027 сек, правил: 0, максимальная длина: 0  |
# └--------------------------------------------------------┘

# %%
conf_example = 0.2
rules_to_show = rules_by_confidence[conf_example]

print(f"\nПравила при confidence = {conf_example}\n")

for _, row in rules_to_show.iterrows():
    antecedent = ", ".join(list(row["antecedents"]))
    consequent = ", ".join(list(row["consequents"]))
    print(f"{antecedent} ==> {consequent}")
# Out:
# Правила при confidence = 0.2
#
# авокадо ==> минеральная вода
# блинчики ==> картофель-фри
# блинчики ==> макароны
# блинчики ==> минеральная вода
# блинчики ==> шоколад
# блинчики ==> яйца
# гамбургер ==> зеленый чай
# гамбургер ==> картофель-фри
# гамбургер ==> макароны
# гамбургер ==> минеральная вода
# гамбургер ==> молоко
# гамбургер ==> яйца
# говяжий фарш ==> макароны
# макароны ==> говяжий фарш
# говяжий фарш ==> минеральная вода
# говяжий фарш ==> молоко
# оливковое масло ==> говяжий фарш
# тертый сыр ==> говяжий фарш
# травы и перец ==> говяжий фарш
# говяжий фарш ==> шоколад
# говяжий фарш ==> яйца
# креветки ==> замороженные овощи
# замороженные овощи ==> макароны
# замороженные овощи ==> минеральная вода
# замороженные овощи ==> молоко
# помидоры ==> замороженные овощи
# замороженные овощи ==> шоколад
# замороженные овощи ==> яйца
# замороженный смузи ==> картофель-фри
# замороженный смузи ==> макароны
# замороженный смузи ==> минеральная вода
# замороженный смузи ==> молоко
# замороженный смузи ==> шоколад
# зеленый чай ==> картофель-фри
# зеленый чай ==> макароны
# зеленый чай ==> минеральная вода
# индейка ==> макароны
# индейка ==> минеральная вода
# индейка ==> яйца
# торт ==> картофель-фри
# картофель-фри ==> шоколад
# шоколад ==> картофель-фри
# эскалоп ==> картофель-фри
# картофель-фри ==> яйца
# яйца ==> картофель-фри
# красное вино ==> макароны
# красное вино ==> минеральная вода
# креветки ==> макароны
# креветки ==> минеральная вода
# креветки ==> молоко
# креветки ==> шоколад
# курица ==> макароны
# курица ==> минеральная вода
# курица ==> молоко
# курица ==> шоколад
# курица ==> яйца
# лосось ==> макароны
# лосось ==> минеральная вода
# лосось ==> шоколад
# мед ==> макароны
# минеральная вода ==> макароны
# макароны ==> минеральная вода
# молоко ==> макароны
# низкокалорийный йогурт ==> макароны
# оливковое масло ==> макароны
# перец ==> макароны
# помидоры ==> макароны
# растительное масло ==> макароны
# рис ==> макароны
# суп ==> макароны
# тертый сыр ==> макароны
# торт ==> макароны
# травы и перец ==> макароны
# макароны ==> шоколад
# шоколад ==> макароны
# эскалоп ==> макароны
# яйца ==> макароны
# макароны ==> яйца
# мед ==> минеральная вода
# молоко ==> минеральная вода
# минеральная вода ==> молоко
# низкокалорийный йогурт ==> минеральная вода
# оливковое масло ==> минеральная вода
# помидоры ==> минеральная вода
# растительное масло ==> минеральная вода
# рис ==> минеральная вода
# свежий хлеб ==> минеральная вода
# суп ==> минеральная вода
# тертый сыр ==> минеральная вода
# торт ==> минеральная вода
# травы и перец ==> минеральная вода
# хлопья ==> минеральная вода
# минеральная вода ==> шоколад
# шоколад ==> минеральная вода
# эскалоп ==> минеральная вода
# яйца ==> минеральная вода
# минеральная вода ==> яйца
# оливковое масло ==> молоко
# помидоры ==> молоко
# растительное масло ==> молоко
# суп ==> молоко
# молоко ==> шоколад
# молоко ==> яйца
# низкокалорийный йогурт ==> яйца
# оливковое масло ==> шоколад
# помидоры ==> шоколад
# растительное масло ==> шоколад
# растительное масло ==> яйца
# рис ==> шоколад
# суп ==> шоколад
# тертый сыр ==> шоколад
# торт ==> яйца
# травы и перец ==> яйца
# шампанское ==> шоколад
# эскалоп ==> шоколад
# шоколад ==> яйца
# блинчики, минеральная вода ==> макароны
# блинчики, макароны ==> минеральная вода
# говяжий фарш, минеральная вода ==> макароны
# говяжий фарш, макароны ==> минеральная вода
# минеральная вода, макароны ==> говяжий фарш
# говяжий фарш, молоко ==> минеральная вода
# говяжий фарш, минеральная вода ==> молоко
# молоко, минеральная вода ==> говяжий фарш
# говяжий фарш, минеральная вода ==> шоколад
# говяжий фарш, шоколад ==> минеральная вода
# минеральная вода, шоколад ==> говяжий фарш
# говяжий фарш, яйца ==> минеральная вода
# говяжий фарш, минеральная вода ==> яйца
# минеральная вода, замороженные овощи ==> макароны
# макароны, замороженные овощи ==> минеральная вода
# минеральная вода, макароны ==> замороженные овощи
# молоко, минеральная вода ==> замороженные овощи
# молоко, замороженные овощи ==> минеральная вода
# минеральная вода, замороженные овощи ==> молоко
# картофель-фри, минеральная вода ==> макароны
# картофель-фри, макароны ==> минеральная вода
# молоко, минеральная вода ==> макароны
# молоко, макароны ==> минеральная вода
# минеральная вода, макароны ==> молоко
# минеральная вода, оливковое масло ==> макароны
# макароны, оливковое масло ==> минеральная вода
# минеральная вода, макароны ==> шоколад
# минеральная вода, шоколад ==> макароны
# шоколад, макароны ==> минеральная вода
# яйца, минеральная вода ==> макароны
# яйца, макароны ==> минеральная вода
# минеральная вода, макароны ==> яйца
# молоко, макароны ==> шоколад
# молоко, шоколад ==> макароны
# шоколад, макароны ==> молоко
# яйца, макароны ==> шоколад
# яйца, шоколад ==> макароны
# шоколад, макароны ==> яйца
# молоко, минеральная вода ==> шоколад
# молоко, шоколад ==> минеральная вода
# минеральная вода, шоколад ==> молоко
# молоко, минеральная вода ==> яйца
# молоко, яйца ==> минеральная вода
# яйца, минеральная вода ==> молоко
# яйца, минеральная вода ==> шоколад
# яйца, шоколад ==> минеральная вода
# минеральная вода, шоколад ==> яйца

# %%
results_df = pd.DataFrame(summary_rules)
results_df
# Out:
#     confidence  time_sec  total_rules  max_rule_length
# 0         0.10  0.008746          333                3
# 1         0.15  0.007182          231                3
# 2         0.20  0.006572          163                3
# 3         0.25  0.005969           99                3
# 4         0.30  0.005398           65                3
# 5         0.35  0.005959           34                3
# 6         0.40  0.006021           19                3
# 7         0.45  0.005867            6                3
# 8         0.50  0.003939            2                3
# 9         0.55  0.002738            0                0
# 10        0.60  0.002646            0                0
# 11        0.70  0.002749            0                0

# %%
plt.figure()
plt.plot(results_df["confidence"], results_df["time_sec"])
plt.xlabel("Достоверность")
plt.ylabel("Быстродействие (сек)")
plt.title("Быстродействие поиска правил")
plt.show()

# %%
plt.figure()
plt.plot(results_df["confidence"], results_df["total_rules"])
plt.xlabel("Достоверность")
plt.ylabel("Всего правил")
plt.title("Общее количество правил")
plt.show()

# %%
plt.figure()
plt.plot(results_df["confidence"], results_df["max_rule_length"])
plt.xlabel("Достоверность")
plt.ylabel("Максимальная длина правила")
plt.title("Максимальное число объектов в правиле")
plt.show()
